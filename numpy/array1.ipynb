# %%
import numpy as np 

a = np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
print(a+1)
print(a*2)
# Out:
# [2 3 4]
# [2 4 6]

# %%
b = np.array([4,5,6])
print(a+b)
print(a*b)
# Out:
# [5 7 9]
# [ 4 10 18]

# %%
print(a**2)
# Out:
# [1 4 9]

# %%
print(b/2)
# Out:
# [2.  2.5 3. ]

# %%
mat = np.array([
    [1,2],
    [3,4]
])
print(mat+10)
print(mat*2)
# Out:
# [[11 12]
#  [13 14]]
# [[2 4]
#  [6 8]]
