# %%
import numpy as np 
mat = np.array([
    [1,2,3],
    [4,5,6]
])
print(mat)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(mat.ndim)
print(mat.shape)
# Out:
# 2
# (2, 3)

# %%
print(mat[0,0])
print(mat[1,2])
# Out:
# 1
# 6

# %%
print(mat[:,0])
print(mat[:,1])
# Out:
# [1 4]
# [2 5]

# %%
print(mat*2)
# Out:
# [[ 2  4  6]
#  [ 8 10 12]]

# %%
m = np.array([
    [10,20],
    [30,40]
])

print(m.shape)
print(m[1,0])
print(m[:,1])
print(m+5)
# Out:
# (2, 2)
# 30
# [20 40]
# [[15 25]
#  [35 45]]
