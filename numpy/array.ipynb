# %%
import numpy  as np 
a = np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
lst = [1,2,3]
print(lst*2)
print(a*2)
# Out:
# [1, 2, 3, 1, 2, 3]
# [2 4 6]

# %%
print(a.ndim)
print(a.shape)
print(a.dtype)
# Out:
# 1
# (3,)
# int64

# %%
print(a[0]) #first element
print(a[1])
# Out:
# 1
# 2

# %%
print(a[0:2])
# Out:
# [1 2]

# %%
b = np.array([5,10,15])
print(b*3)
print(b[1])
# Out:
# [15 30 45]
# 10
